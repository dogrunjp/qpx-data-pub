# %% [markdown]
# # Skunk cabbage (Symplocarpus renifolius) Hot_F / Hot_P
#
# - Maps: FigS10A/B/C_qpx.gpml in `skunk_cabbage/gpml/`
# - Gene expression: `annotation_Hot_qpx.tsv` (xref_id = Araport11 AGI ID)
# - Metabolome: `metabolome_Hot_qpx.tsv` (xref_id = ChEBI ID)

# %%
expression_data_path = [
    'skunk_cabbage/data/annotation_Hot_qpx.tsv',
    'skunk_cabbage/data/metabolome_Hot_qpx.tsv'
]

# %%
import qpx_widgets
visualizer = qpx_widgets.GpmlD3Visualizer(
    expression_data_path=expression_data_path,
    gpml_dir_path='skunk_cabbage/gpml',
    expression_columns_index=[4, 4],
)
visualizer.show()
